# %%
import pydicom as dicom
import matplotlib.pylab as plt
import pydicom as dicom

# %% [markdown]
# # N300-Cancer

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\N300-Cancer\9220988_PARKBYUNGSAM^^^^_003.Dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\N300-Cancer\9220988_PARKBYUNGSAM^^^^_009.Dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\N300-Cancer\9220988_PARKBYUNGSAM^^^^_016.Dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\N300-Cancer\9220988_PARKBYUNGSAM^^^^_022.Dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\N300-Cancer\6439483_LEESANGKOOK^^^^_008.Dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %% [markdown]
# # TBx_001 ~ 402

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\TBx_001~402\ser001img00006.dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\TBx_001~402\ser001img00016.dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %% [markdown]
# # TRUS(Health0001-0790)

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\TRUS(Health0001-0790)\img015.dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\TRUS(Health0001-0790)\ser001img00007.dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %% [markdown]
# # SinChon_TBx_0001

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\SinChon_TBx_0001\ser001img00004.dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\SinChon_TBx_0001\ser001img00005.dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %% [markdown]
# # US_AI

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\US_AI\ser001img00016.dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %% [markdown]
# # GangNam

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\GangNam_TBx\ser001img00005.dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)
