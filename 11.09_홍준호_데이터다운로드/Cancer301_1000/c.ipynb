# %%
import pydicom as dicom
import matplotlib.pylab as plt
import pydicom as dicom

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\Cancer301_1000\6751359_KIMHWASOON_003.Dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\Cancer301_1000\6890294_HONGSUNGYUB^^^^_007.Dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)

# %%
image_path = r'C:\Users\user\Desktop\vsc\Severance_Hospital\11.09_홍준호_데이터다운로드\Cancer301_1000\9199142_HUHEUNHOI^^^^_013.Dcm'
ds = dicom.dcmread(image_path)
plt.imshow(ds.pixel_array)
