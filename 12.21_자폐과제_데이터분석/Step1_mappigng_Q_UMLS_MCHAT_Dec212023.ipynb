# %%
import os
pt=os.getcwd()
pt
# Out:
# '/home/skbae/Documents/skbae/ASD/PJT_Data'

# %%
import PyPDF2
import pandas as pd


# Open the PDF file in binary mode
with open(pt+"/Questions/Mchat_en.pdf", 'rb') as pdf_file:
    # Create a PDF object
    pdf_reader = PyPDF2.PdfReader(pdf_file)

    # Initialize an empty list to store the text lines
    text_lines = []

    # Loop through each page in the PDF
    for page in pdf_reader.pages:
        # Extract text from the page and split it into lines
        lines = page.extract_text().split('\n')
        
        # Append each line to the text_lines list
        text_lines.extend(lines)

# Create a DataFrame from the text_lines list
df_mchat_eg = pd.DataFrame({'Text': text_lines})

# Display the DataFrame
df_mchat_eg
# Out:
#                                                  Text
# 0                      Child’s Name  Filled out by:
# 1              Date of Birth  Relationship to child
# 2                                     Today’s date
# 3
# 4
# 5   Modified Checklist for Autism in Toddlers (M-C...
# 6
# 7   Please fill out the following about how your c...
# 8   is rare (e.g., you've seen it once or twice), ...
# 9   1. Does your child enjoy being sw ung, bounced...
# 10  2. Does your child take an interest in other c...
# 11  3. Does your child like climbing on things, su...
# 12  4. Does your child enjoy pl aying peek-a-boo/h...
# 13  5. Does your child ever pretend, for example, ...
# 14                      pretend other things? Yes No
# 15  6. Does your child ever use his/her index fing...
# 16  7. Does your child ever use his/her index fing...
# 17  8. Can your child play properly with small toy...
# 18                fiddling, or dropping them? Yes No
# 19  9. Does your child ever bring objects over to ...
# 20  10. Does your child look you in the eye for mo...
# 21  11. Does your child ever seem overse nsitive t...
# 22  12. Does your child smile in response to your ...
# 23  13. Does your child imitate you? (e.g., you ma...
# 24  14. Does your child respond to his/her name wh...
# 25  15. If you point at a toy across the room, doe...
# 26                  16. Does your child walk? Yes No
# 27  17. Does your child look at things you are loo...
# 28  18. Does your child make unusual finger moveme...
# 29  19. Does your child try to attract your  atten...
# 30  20. Have you ever wondered if your child is de...
# 31  21. Does your child understand what people say...
# 32  21. Does your child sometimes stare at nothing...
# 33  23. Does your child look at your face to chec ...
# 34                                unfamiliar? Yes No
# 35  ©1999 Diana Robins, Deborah Fein, & Marianne B...
# 36                http://www.dbpeds.org/media/mchat

# %%
# check the data bgin

# %%
df_mchat_eg['Text'][9]
# Out:
# '1. Does your child enjoy being sw ung, bounced on your knee, etc.? Yes No '

# %%
df_mchat_eg['Text'][10]
# Out:
# '2. Does your child take an interest in other children? Yes No '

# %%
df_mchat_eg['Text'][11]
# Out:
# '3. Does your child like climbing on things, such as up stairs? Yes No '

# %%
df_mchat_eg['Text'][33]
# Out:
# '23. Does your child look at your face to chec k your reaction when faced with something '

# %%
df_mchat_eg_F=df_mchat_eg[9:34]
df_mchat_eg_F
# Out:
#                                                  Text
# 9   1. Does your child enjoy being sw ung, bounced...
# 10  2. Does your child take an interest in other c...
# 11  3. Does your child like climbing on things, su...
# 12  4. Does your child enjoy pl aying peek-a-boo/h...
# 13  5. Does your child ever pretend, for example, ...
# 14                      pretend other things? Yes No
# 15  6. Does your child ever use his/her index fing...
# 16  7. Does your child ever use his/her index fing...
# 17  8. Can your child play properly with small toy...
# 18                fiddling, or dropping them? Yes No
# 19  9. Does your child ever bring objects over to ...
# 20  10. Does your child look you in the eye for mo...
# 21  11. Does your child ever seem overse nsitive t...
# 22  12. Does your child smile in response to your ...
# 23  13. Does your child imitate you? (e.g., you ma...
# 24  14. Does your child respond to his/her name wh...
# 25  15. If you point at a toy across the room, doe...
# 26                  16. Does your child walk? Yes No
# 27  17. Does your child look at things you are loo...
# 28  18. Does your child make unusual finger moveme...
# 29  19. Does your child try to attract your  atten...
# 30  20. Have you ever wondered if your child is de...
# 31  21. Does your child understand what people say...
# 32  21. Does your child sometimes stare at nothing...
# 33  23. Does your child look at your face to chec ...

# %%
# check the data end

# %%
import PyPDF2
import pandas as pd
import re

# Open the PDF file in binary mode
with open(pt+"/Questions/M-CHAT_kr.pdf", 'rb') as pdf_file:
    # Create a PDF object
    pdf_reader = PyPDF2.PdfReader(pdf_file)
    # Initialize an empty string to store the text
    text = ''

    # Loop through each page in the PDF
    for page_num in range(len(pdf_reader.pages)):
        # Extract text from the page and add a newline character between pages
        page = pdf_reader.pages[page_num]
        text += page.extract_text() + '\n'

# Use regular expression to split the text based on numbers
text_lines = re.split(r'\d+\s*', text.strip())

# Create a DataFrame from the text_lines list
df = pd.DataFrame({'Text': text_lines})
df
# Out:
#                                                  Text
# 0   !평상시 당신의 아이 행동을 기준으로 평가하시고 만약에 몇 번 이러한 행동을 보였지...
# 1   당신이 아이를 안고 그네처럼 흔들어 주거나 무릎에 앉혀 흔들어 주는 것을 아이가 좋...
# 2                              아이가 다른 아이들에게 관심을 가지나요?
# 3                   아이가 물건이나 가구에 올라가거나 계단 오르기를 좋아합니까?
# 4                             아이가 까꿍 놀이나 숨바꼭질을 좋아합니까?
# 5           아이가 흉내 놀이를 하나요 예 인형돌보기 전화걸기 놀이 등? ( : , )
# 6                        아이가 뭔가를 요구할 때 검지손가락으로 가리킵니까?
# 7                   아이가 흥미로운 것을 가리키기 위해 검지손가락을 사용합니까?
# 8   아이가 자동차나 블록과 같은 작은 장난감을 입으로 빨거나 반복적으로 떨어뜨리지 않고...
# 9              아이가 당신에게 보여주기 위해 장난감이나 기타 물건을 가지고 오나요?
# 10                          아이가 초에서 초 이상 당신의 눈을 응시하나요
# 11                                                  ?
# 12         아이가 소리에 민감하다고 느끼시나요 예 시끄러워 귀를 막는 행동? ( : )
# 13                 당신의 얼굴을 보면 미소를 짓거나 당신이 웃으면 따라 웃나요?
# 14               아이가 당신을 따라 하나요 예 찡그리면 따라서 찡그림? ( : )
# 15                           아이가 이름을 부르면 아이가 반응을 하나요?
# 16               당신이 멀리 있는 물건을 손으로 가리키면 아이가 그 쪽을 보나요?
# 17                                       아이가 걸어 다니나요?
# 18                           아이가 당신이 보고 있는 것을 따라 보나요?
# 19                 아이가 자신의 얼굴 주위에서 손가락으로 특이한 행동을 하나요?
# 20                      아이가 자신의 행동으로 당신의 관심을 끌려고 하나요?
# 21                        아이의 청각에 문제가 있다고 생각한 적이 있나요?
# 22                               아이가 다른 사람의 말을 이해하나요?
# 23                        아이가 허공을 응시하거나 목적 없이 돌아다니나요?
# 24          아이가 낯선 것을 봤을 때 당신의 반응을 보기 위해 당신의 얼굴을 보나요?

# %%
df['Text'][1]
# Out:
# '당신이 아이를 안고 그네처럼 흔들어 주거나 무릎에 앉혀 흔들어 주는 것을 아이가 좋아하나요?'

# %%
df['Text'][24]
# Out:
# '아이가 낯선 것을 봤을 때 당신의 반응을 보기 위해 당신의 얼굴을 보나요?'

# %%
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.cluster import KMeans
# from sklearn.metrics.pairwise import linear_kernel
# # 1. Load the data from the original Excel file
# # Load the data from the provided file again
# data = pd.read_csv(pt+"/Questions/Work/cdb_advanced_ASD_F3.csv")


# # 2. Text Preprocessing
# def preprocess_text(text):
#     return " ".join([word.lower() for word in text.split()])
# data['Processed_Name'] = data['Name'].apply(preprocess_text)

# # 3. Vectorization using TF-IDF
# vectorizer = TfidfVectorizer(stop_words='english')
# X_full = vectorizer.fit_transform(data['Processed_Name'])


# # 4. KMeans clustering with 100 clusters (assuming it was done earlier)
# kmeans_100 = KMeans(n_clusters=100, random_state=42).fit(X_full)
# data['100_Cluster'] = kmeans_100.predict(X_full)

# # Function to find best matches in dataset based on the processed text and include rank : TFIDF
# def match_question_to_data_detailed(question, data, vectorizer, top_n=None):
#     question_vec = vectorizer.transform([preprocess_text(question)])
#     cosine_similarities = linear_kernel(question_vec, X_full).flatten()
#     if top_n:
#         related_docs_indices = cosine_similarities.argsort()[-top_n:][::-1]
#     else:
#         related_docs_indices = cosine_similarities.argsort()[::-1]
#     matched_data = data.iloc[related_docs_indices]
#     matched_data['Question']= question
#     matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
#     return matched_data

# # Find the best matches for each question with detailed information
# question_matches_detailed_ranked = {}
# for idx, question in enumerate(df_mchat_eg_F['Text']):
# # for idx, question in enumerate(df_mchat_eg_F):
#     matched_data = match_question_to_data_detailed(question, data, vectorizer)
#     question_matches_detailed_ranked[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]

# # 8. Save the results to an Excel file
# output_filepath_questions_detailed_ranked = pt+"/Questions/Work/output_questions_detailed_ranked_dec21.xlsx"
# writer = pd.ExcelWriter(output_filepath_questions_detailed_ranked, engine='xlsxwriter')
# for q_key, matched_data in question_matches_detailed_ranked.items():
#     # Add the question as a separate row before the matches
#     dataframe = pd.DataFrame([[q_key, None, None, None,None,None, None, None]], columns=['Question','ID', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria',  'Matching Rank/Probability', '100_Cluster'])
#     dataframe = pd.concat([dataframe, matched_data], ignore_index=True)
#     dataframe.to_excel(writer, sheet_name=q_key, index=False)
# writer.save()

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import linear_kernel
# 1. Load the data from the original Excel file
# Load the data from the provided file again
data = pd.read_csv(pt+"/Questions/Work/cdb_advanced_ASD_F3.csv")


# 2. Text Preprocessing
def preprocess_text(text):
    return " ".join([word.lower() for word in text.split()])
data['Processed_Name'] = data['Name'].apply(preprocess_text)

# %%
# 3. Vectorization using TF-IDF
vectorizer = TfidfVectorizer(stop_words='english')
X_full = vectorizer.fit_transform(data['Processed_Name'])


# 4. KMeans clustering with 100 clusters (assuming it was done earlier)
kmeans_100 = KMeans(n_clusters=100, random_state=42).fit(X_full)
data['100_Cluster'] = kmeans_100.predict(X_full)
# Out:
# /home/skbae/anaconda3/envs/myNLP/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'DSM5 Criteria', 'Symptom of DSM5 Criteria', 'CUI',
#        'Unnamed: 5', 'Processed_Name', '100_Cluster'],
#       dtype='object')

# %%
data.head()
# Out:
#         ID                                               Name DSM5 Criteria  \
# 0  ASD0001        inflexible adherence to routines or rituals            B2
# 1  ASD0002                impaired use of nonverbal behaviors            B2
# 2  ASD0003  speech nonverbal communication skills facial e...            A2
# 3  ASD0004                         abnormal sensations in eye            A2
# 4  ASD0005          social/emotional reciprocity appears deaf            A1
#
#                     Symptom of DSM5 Criteria       CUI Unnamed: 5  \
# 0           inflexible adherence to routines  C1837653        NaN
# 1  ritualized patterns of nonverbal behavior  C4021798        NaN
# 2                    nonverbal communication  C2018050        NaN
# 3               abnormalities in eye contact  C0497201        NaN
# 4               social-emotional reciprocity  C4064026        NaN
#
#                                       Processed_Name  100_Cluster
# 0        inflexible adherence to routines or rituals           69
# 1                impaired use of nonverbal behaviors           48
# 2  speech nonverbal communication skills facial e...           91
# 3                         abnormal sensations in eye           64
# 4          social/emotional reciprocity appears deaf           24

# %%
# Function to find best matches in dataset based on the processed text and include rank : TFIDF
def match_question_to_data_detailed(question, data, vectorizer, top_n=None):
    question_vec = vectorizer.transform([preprocess_text(question)])
    cosine_similarities = linear_kernel(question_vec, X_full).flatten()
    if top_n:
        related_docs_indices = cosine_similarities.argsort()[-top_n:][::-1]
    else:
        related_docs_indices = cosine_similarities.argsort()[::-1]
    matched_data = data.iloc[related_docs_indices]
    matched_data['Question']= question
    matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
    return matched_data
# 6. List of Translated Questions
# questions_english = [
#     "When you call your child's name, does the child look at you?",
#     "How easy is it for you to make eye contact with your child?",
#     "When your child plays alone, do they line up objects?",
#     "Do other people easily understand what your child says?",
#     "Does your child point with their finger to express what they want (e.g., a toy that's far away)?",
#     "Does your child point with their finger to share interest with you (e.g., at an interesting sight)?"
# ] # df_mchat_eg_F['Text']

#questions_english = df_mchat_eg_F['Text']

# %%
df_mchat_eg_F['Text']
# Out:
# 9     1. Does your child enjoy being sw ung, bounced...
# 10    2. Does your child take an interest in other c...
# 11    3. Does your child like climbing on things, su...
# 12    4. Does your child enjoy pl aying peek-a-boo/h...
# 13    5. Does your child ever pretend, for example, ...
# 14                        pretend other things? Yes No
# 15    6. Does your child ever use his/her index fing...
# 16    7. Does your child ever use his/her index fing...
# 17    8. Can your child play properly with small toy...
# 18                  fiddling, or dropping them? Yes No
# 19    9. Does your child ever bring objects over to ...
# 20    10. Does your child look you in the eye for mo...
# 21    11. Does your child ever seem overse nsitive t...
# 22    12. Does your child smile in response to your ...
# 23    13. Does your child imitate you? (e.g., you ma...
# 24    14. Does your child respond to his/her name wh...
# 25    15. If you point at a toy across the room, doe...
# 26                    16. Does your child walk? Yes No
# 27    17. Does your child look at things you are loo...
# 28    18. Does your child make unusual finger moveme...
# 29    19. Does your child try to attract your  atten...
# 30    20. Have you ever wondered if your child is de...
# 31    21. Does your child understand what people say...
# 32    21. Does your child sometimes stare at nothing...
# 33    23. Does your child look at your face to chec ...
# Name: Text, dtype: object

# %%
# Find the best matches for each question with detailed information
question_matches_detailed_ranked = {}
for idx, question in enumerate(df_mchat_eg_F['Text']):
# for idx, question in enumerate(df_mchat_eg_F):
    matched_data = match_question_to_data_detailed(question, data, vectorizer)
    question_matches_detailed_ranked[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]
# Out:
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/85854111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/85854111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]

# %%
#question_matches_detailed_ranked

# %%
#question_matches_detailed_ranked.items()

# %%
# # 7. Find the best matches for each question with detailed information
# question_matches_detailed_ranked = {}
# for idx, question in enumerate(df_mchat_eg_F['Text']):
# # for idx, question in enumerate(df_mchat_eg_F):
#     matched_data = match_question_to_data_detailed(question, data, vectorizer)
#     question_matches_detailed_ranked[f"Question {idx}"] = matched_data[['ID', 'Name', 'CUI', 'Matching Rank/Probability', '100_Cluster']]
# 8. Save the results to an Excel file
output_filepath_questions_detailed_ranked = pt+"/Questions/Work/output_questions_detailed_ranked_dec21.xlsx"
writer = pd.ExcelWriter(output_filepath_questions_detailed_ranked, engine='xlsxwriter')
for q_key, matched_data in question_matches_detailed_ranked.items():
    # Add the question as a separate row before the matches
    dataframe = pd.DataFrame([[q_key, None, None, None,None,None, None, None]], columns=['Question','ID', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria',  'Matching Rank/Probability', '100_Cluster'])
    dataframe = pd.concat([dataframe, matched_data], ignore_index=True)
    dataframe.to_excel(writer, sheet_name=q_key, index=False)
writer.save()

# %%
# Snetence Transformer

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
# 1. Load the data from the original Excel file

data2 = pd.read_csv(pt+"/Questions/Work/cdb_advanced_ASD_F3.csv")
# 2. Text Preprocessing
def preprocess_text(text):
    return " ".join([word.lower() for word in text.split()])
data2['Processed_Name'] = data2['Name'].apply(preprocess_text)
# 3. Vectorization using Sentence Transformers
model = SentenceTransformer('all-MiniLM-L6-v2')  # You can choose any model
X_full2 = model.encode(data2['Processed_Name'].tolist())

# 4. KMeans clustering with 100 clusters (assuming it was done earlier)
kmeans_100 = KMeans(n_clusters=100, random_state=42).fit(X_full2)
data2['100_Cluster'] = kmeans_100.predict(X_full2)
# Out:
# /home/skbae/anaconda3/envs/myNLP/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import torch
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Check if CUDA is available and set the device accordingly
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# 1. Load the data from the original Excel file
data = pd.read_csv(pt+"/Questions/Work/cdb_advanced_ASD_F3.csv")

# 2. Text Preprocessing
def preprocess_text(text):
    return " ".join([word.lower() for word in text.split()])
data['Processed_Name'] = data['Name'].apply(preprocess_text)

# 3. Vectorization using Sentence Transformers
model = SentenceTransformer('all-MiniLM-L6-v2')  # replace with your model
model = model.to(device)  # Move the model to the device
X_full = model.encode(data['Processed_Name'].tolist(), convert_to_tensor=True)
X_full = X_full.to(device)  # Move X_full to the device

# 4. KMeans clustering with 100 clusters (assuming it was done earlier)
kmeans_100 = KMeans(n_clusters=100, random_state=42).fit(X_full.cpu())  # KMeans requires CPU tensor
data['100_Cluster'] = kmeans_100.predict(X_full.cpu())  # KMeans requires CPU tensor

# Function to find best matches in dataset based on the processed text and include rank
def match_question_to_data_detailed(question, data, model, top_n=None):
    question_vec = model.encode([preprocess_text(question)], convert_to_tensor=True)
    question_vec = question_vec.to(device)  # Move tensor to the device
    cosine_similarities = cosine_similarity(question_vec.cpu(), X_full.cpu()).flatten()  # Compute cosine similarity on CPU
    if top_n:
        related_docs_indices = cosine_similarities.argsort()[-top_n:][::-1]
    else:
        related_docs_indices = cosine_similarities.argsort()[::-1]
    matched_data = data.iloc[related_docs_indices]
    matched_data['Question']= question
    matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
    return matched_data

# Find the best matches for each question with detailed information
question_matches_detailed_ranked = {}
for idx, question in enumerate(df_mchat_eg_F['Text']):
    matched_data = match_question_to_data_detailed(question, data, model)
    question_matches_detailed_ranked[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]

# 8. Save the results to an Excel file
output_filepath_questions_detailed_ranked = pt+"/Questions/Work/output_questions_detailed_ST_ranked_dec21.xlsx"
writer = pd.ExcelWriter(output_filepath_questions_detailed_ranked, engine='xlsxwriter')
for q_key, matched_data in question_matches_detailed_ranked.items():
    # Add the question as a separate row before the matches
    dataframe = pd.DataFrame([[q_key, None, None, None,None,None, None, None]], columns=['Question','ID', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria',  'Matching Rank/Probability', '100_Cluster'])
    dataframe = pd.concat([dataframe, matched_data], ignore_index=True)
    dataframe.to_excel(writer, sheet_name=q_key, index=False)
writer.save()
# Out:
# /home/skbae/anaconda3/envs/myNLP/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# /tmp/ipykernel_96652/2294040139.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# /tmp/ipykernel_96652/2294040139.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]

# %%
# Function to find best matches in dataset based on the processed text and include rank
def match_question_to_data_detailed(question, data, model, top_n=None):
    question_vec = model.encode([preprocess_text(question)])
    cosine_similarities = cosine_similarity(question_vec, X_full).flatten()
    if top_n:
        related_docs_indices = cosine_similarities.argsort()[-top_n:][::-1]
    else:
        related_docs_indices = cosine_similarities.argsort()[::-1]
    matched_data = data.iloc[related_docs_indices]
    matched_data['Question']= question
    matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
    return matched_data

# Find the best matches for each question with detailed information
question_matches_detailed_ranked = {}
for idx, question in enumerate(df_mchat_eg_F['Text']):
    matched_data = match_question_to_data_detailed(question, data, model)
    question_matches_detailed_ranked[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]

# 8. Save the results to an Excel file
# output_filepath_questions_detailed_ranked = pt+"/Questions/Work/output_questions_detailed_ranked_dec21.xlsx"
output_filepath_questions_detailed_ranked = pt+"/Questions/Work/output_questions_detailed_ST_ranked_dec21.xlsx"
writer = pd.ExcelWriter(output_filepath_questions_detailed_ranked, engine='xlsxwriter')
for q_key, matched_data in question_matches_detailed_ranked.items():
    # Add the question as a separate row before the matches
    dataframe = pd.DataFrame([[q_key, None, None, None,None,None, None, None]], columns=['Question','ID', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria',  'Matching Rank/Probability', '100_Cluster'])
    dataframe = pd.concat([dataframe, matched_data], ignore_index=True)
    dataframe.to_excel(writer, sheet_name=q_key, index=False)
writer.save()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_96652/2890179829.py in <cell line: 16>()
#      15 question_matches_detailed_ranked = {}
#      16 for idx, question in enumerate(df_mchat_eg_F['Text']):
# ---> 17     matched_data = match_question_to_data_detailed(question, data, model)
#      18     question_matches_detailed_ranked[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]
#      19
#
# /tmp/ipykernel_96652/2890179829.py in match_question_to_data_detailed(question, data, model, top_n)
#       2 def match_question_to_data_detailed(question, data, model, top_n=None):
#       3     question_vec = model.encode([preprocess_text(question)])
# ----> 4     cosine_similarities = cosine_similarity(question_vec, X_full).flatten()
#       5     if top_n:
#       6         related_docs_indices = cosine_similarities.argsort()[-top_n:][::-1]
#
# ~/anaconda3/envs/myNLP/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in cosine_similarity(X, Y, dense_output)
#    1391     # to avoid recursive import
#    1392
# -> 1393     X, Y = check_pairwise_arrays(X, Y)
#    1394
#    1395     X_normalized = normalize(X, copy=True)
#
# ~/anaconda3/envs/myNLP/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     178             )
#     179     elif X.shape[1] != Y.shape[1]:
# --> 180         raise ValueError(
#     181             "Incompatible dimension for X and Y matrices: "
#     182             "X.shape[1] == %d while Y.shape[1] == %d" % (X.shape[1], Y.shape[1])
#
# ValueError: Incompatible dimension for X and Y matrices: X.shape[1] == 384 while Y.shape[1] == 2385

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
# 1. Load the data from the original Excel file

data2 = pd.read_csv(pt+"/Questions/Work/cdb_advanced_ASD_F3.csv")
# 2. Text Preprocessing
def preprocess_text(text):
    return " ".join([word.lower() for word in text.split()])
data2['Processed_Name'] = data2['Name'].apply(preprocess_text)
# 3. Vectorization using Sentence Transformers
model = SentenceTransformer('all-MiniLM-L6-v2')  # You can choose any model
X_full2 = model.encode(data2['Processed_Name'].tolist())


# 4. KMeans clustering with 100 clusters (assuming it was done earlier)
kmeans_100 = KMeans(n_clusters=100, random_state=42).fit(X_full2)
data2['100_Cluster'] = kmeans_100.predict(X_full2)
# 5. Function to find best matches in dataset based on the processed text and include rank
# def match_question_to_data_detailed(data, model, top_n=None):
#     question_vec = model.encode([preprocess_text(text) for text in df_mchat_eg_F['Text']])
#     cosine_similarities = cosine_similarity(question_vec, X_full).flatten()
#     if top_n:
#         related_docs_indices = cosine_similarities.argsort()[-top_n:][::-1]
#     else:
#         related_docs_indices = cosine_similarities.argsort()[::-1]
#     matched_data = data.iloc[related_docs_indices]
#     matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
#     return matched_data


def match_question_to_data_detailed(data, model, top_n=None):
    question_vec = model.encode([preprocess_text(text) for text in df_mchat_eg_F['Text']])
    cosine_similarities = cosine_similarity(question_vec, X_full).flatten()
    if top_n:
        related_docs_indices = cosine_similarities.argsort()[-top_n:][::-1]
    else:
        related_docs_indices = cosine_similarities.argsort()[::-1]
    matched_data = data.iloc[related_docs_indices]
    matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
    return matched_data
# Out:
# /home/skbae/anaconda3/envs/myNLP/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data2.head()
# Out:
#         ID                                               Name DSM5 Criteria  \
# 0  ASD0001        inflexible adherence to routines or rituals            B2
# 1  ASD0002                impaired use of nonverbal behaviors            B2
# 2  ASD0003  speech nonverbal communication skills facial e...            A2
# 3  ASD0004                         abnormal sensations in eye            A2
# 4  ASD0005          social/emotional reciprocity appears deaf            A1
#
#                     Symptom of DSM5 Criteria       CUI Unnamed: 5  \
# 0           inflexible adherence to routines  C1837653        NaN
# 1  ritualized patterns of nonverbal behavior  C4021798        NaN
# 2                    nonverbal communication  C2018050        NaN
# 3               abnormalities in eye contact  C0497201        NaN
# 4               social-emotional reciprocity  C4064026        NaN
#
#                                       Processed_Name  100_Cluster
# 0        inflexible adherence to routines or rituals           55
# 1                impaired use of nonverbal behaviors           41
# 2  speech nonverbal communication skills facial e...           41
# 3                         abnormal sensations in eye           80
# 4          social/emotional reciprocity appears deaf           31

# %%
def match_question_to_data_detailed(question, data, model, top_n=None):
    question_vec = model.encode([preprocess_text(question)])
    # Encode the data using the same model and preprocessing steps
    data_encoded = model.encode([preprocess_text(text) for text in data2['Text']])
    # Compute the full matrix of encoded data
    X_full = np.array(data_encoded)
    cosine_similarities = cosine_similarity(question_vec, X_full).flatten()
    if top_n:
        related_docs_indices = cosine_similarities.argsort()[-top_n:][::-1]
    else:
        related_docs_indices = cosine_similarities.argsort()[::-1]
    matched_data = data.iloc[related_docs_indices]
    matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
    return matched_data



# Find the best matches for each question with detailed information
question_matches_detailed_ranked2 = {}
for idx, question in enumerate(df_mchat_eg_F['Text']):
    matched_data = match_question_to_data_detailed(question, data2, model)
    question_matches_detailed_ranked2[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/myNLP/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/anaconda3/envs/myNLP/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/myNLP/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_96652/2814129705.py in <cell line: 20>()
#      19 question_matches_detailed_ranked2 = {}
#      20 for idx, question in enumerate(df_mchat_eg_F['Text']):
# ---> 21     matched_data = match_question_to_data_detailed(question, data2, model)
#      22     question_matches_detailed_ranked2[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]
#
# /tmp/ipykernel_96652/2814129705.py in match_question_to_data_detailed(question, data, model, top_n)
#       2     question_vec = model.encode([preprocess_text(question)])
#       3     # Encode the data using the same model and preprocessing steps
# ----> 4     data_encoded = model.encode([preprocess_text(text) for text in data['Text']])
#       5     # Compute the full matrix of encoded data
#       6     X_full = np.array(data_encoded)
#
# ~/anaconda3/envs/myNLP/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/anaconda3/envs/myNLP/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Text'

# %%
# Find the best matches for each question with detailed information
question_matches_detailed_ranked2 = {}
for idx, question in enumerate(df_mchat_eg_F['Text']):
    matched_data = match_question_to_data_detailed(question, data2, model)
    question_matches_detailed_ranked2[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_96652/1613893066.py in <cell line: 3>()
#       2 question_matches_detailed_ranked2 = {}
#       3 for idx, question in enumerate(df_mchat_eg_F['Text']):
# ----> 4     matched_data = match_question_to_data_detailed(question, data2, model)
#       5     question_matches_detailed_ranked2[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]
#
# /tmp/ipykernel_96652/3448755011.py in match_question_to_data_detailed(data, model, top_n)
#      30
#      31 def match_question_to_data_detailed(data, model, top_n=None):
# ---> 32     question_vec = model.encode([preprocess_text(text) for text in df_mchat_eg_F['Text']])
#      33     cosine_similarities = cosine_similarity(question_vec, X_full).flatten()
#      34     if top_n:
#
# ~/anaconda3/envs/myNLP/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'encode'

# %%
# Find the best matches for each question with detailed information
question_matches_detailed_ranked2 = {}
for idx, question in enumerate(df_mchat_eg_F['Text']):
# for idx, question in enumerate(df_mchat_eg_F):
    matched_data = match_question_to_data_detailed(question, data2, vectorizer)
    question_matches_detailed_ranked2[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_96652/1343140433.py in <cell line: 3>()
#       3 for idx, question in enumerate(df_mchat_eg_F['Text']):
#       4 # for idx, question in enumerate(df_mchat_eg_F):
# ----> 5     matched_data = match_question_to_data_detailed(question, data2, vectorizer)
#       6     question_matches_detailed_ranked2[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]
#
# /tmp/ipykernel_96652/3448755011.py in match_question_to_data_detailed(data, model, top_n)
#      30
#      31 def match_question_to_data_detailed(data, model, top_n=None):
# ---> 32     question_vec = model.encode([preprocess_text(text) for text in df_mchat_eg_F['Text']])
#      33     cosine_similarities = cosine_similarity(question_vec, X_full).flatten()
#      34     if top_n:
#
# ~/anaconda3/envs/myNLP/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'encode'

# %%
# Save the results to an Excel file

output_filepath_questions_detailed_ranked = pt+"/Questions/Work/output_questions_detailed_ST_ranked_dec21.xlsx"
writer = pd.ExcelWriter(output_filepath_questions_detailed_ranked, engine='xlsxwriter')
for q_key, matched_data in question_matches_detailed_ranked.items():
    # Add the question as a separate row before the matches
    dataframe = pd.DataFrame([[q_key, None, None, None, None, None]], columns=['Question', 'ID', 'Name', 'CUI', 'Matching Rank/Probability', '100_Cluster'])
    dataframe = pd.concat([dataframe, matched_data], ignore_index=True)
    dataframe.to_excel(writer, sheet_name=q_key, index=False)
writer.save()
