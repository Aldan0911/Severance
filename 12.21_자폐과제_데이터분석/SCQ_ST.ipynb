# %%
import PyPDF2
import pandas as pd
import re

# %% [markdown]
# # Data Check

# %%
SCQ_path = r"C:\Users\user\Desktop\vsc\Severance_Hospital\12.21_자폐과제_데이터분석\original\SCQ.pdf"

# %%
# Open the PDF file in binary mode
with open(SCQ_path , 'rb') as pdf_file:
    # Create a PDF object
    pdf_reader = PyPDF2.PdfReader(pdf_file)
    # Initialize an empty string to store the text
    text = ''

    # Loop through each page in the PDF
    for page_num in range(len(pdf_reader.pages)):
        # Extract text from the page and add a newline character between pages
        page = pdf_reader.pages[page_num]
        text += page.extract_text() + '\n'

# Use regular expression to split the text based on numbers
text_lines = re.split(r'\d+\s*', text.strip())

# Create a DataFrame from the text_lines list
SCQ_kr = pd.DataFrame({'Text': text_lines})

# %%
# Define a function to remove unwanted characters
def remove_unwanted_chars(text):
    # Replace '(:,)' and '(:)' with an empty string
    return text.replace('아니오','')

# Apply the function to the entire 'Text' column
SCQ_kr['Text'] = SCQ_kr['Text'].apply(remove_unwanted_chars)

# Drop useless rows
SCQ_kr = SCQ_kr.drop([0, 1, 2, 4, 16, 18, 19, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88])
# index reset
SCQ_kr = SCQ_kr.reset_index(drop=True)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 1000)
SCQ_kr
# Out:
#                                                                                                                                                                                Text
# 0                                                                                                                         피검자는 현재 짧은 어구나 문장을 사용해서 이야기할 수 있습니까?만약 아니라면 번 문제로 건너뛰시오,
# 1                                                                                                 당신은 피검자와 서로 이야기를 주고 받거나 한 가지 주제에 대해 이어서 이야기하는 식으로 피검자와 양방향의 대화를 나눌 수 있습니까`‘ ?예아니요
# 2                                                                                  피검자가 다소 이상한 구를 사용하거나 같은 말을 반복적으로 이야기 한 적이 있습니까 다른 사람이 했던 표현이거나 피검자 자신이 만들어 낸 것 모두 ? ( , 해당됨)예아니요
# 3                                                                                    피검자가 사회적으로 부적절한 질문이나 언급을 한 적이 있습니까 예 피검자가 ? ( : 그렇게 하면 곤란한 상황에서 사적인 질문을 하거나 개인 신상에 관한 언급함)예아니요
# 4                                                                          피검자가 인칭대명사를 혼동해 쓴 적이 있습니까 예 나 물 주세요 대신에 너 ? ( : ` “ `물 줄까 혹은 나 배고파요 대신에 걔가 배고파요 와 같이 표현함?‘ ` ’ ` ‘ )예아니요
# 5                                                피검자가 지어내거나 스스로 만들어 낸 듯한 말을 사용한 적이 있습니까 또는 ? 사물을 기이하고 간접적인 방식으로 지칭하거나 말을 은유적인 방식으로 이야기한 적이 있습니까 예 눈 을 포슬 비라 고 말함? ( : ` ‘ ` ’ )예아니요
# 6                                                                                                    피검자가 같은 말을 완전히 같은 방식으로 몇 번씩 이야기하거나 당신에게 같은 말을 , 몇 번씩 반복해 말하도록 고집한 적이 있습니까?예아니요
# 7                                                                           피검자가 아주 특별한 방식 혹은 특정한 순서대로 하려는 일들이 있었습니까 또는 ? 당신에게 의식(儀의式식을 행하듯이 반드시 정해진 방식대로 행동할 것을 고집하는 것이 )있습니까?예아니요
# 8                                                                                                                     당신이 판단하기에 특정 상황에서 보이는 피검자의 얼굴 표정은 대체로 그 상황에서 , 적절해 보였습니까?예아니요
# 9                                                                         피검자가 당신의 손을 마치 도구나 자신의 몸의 일부분인 것처럼 사용한 적이 있습니까 예 어떤 대상을 당신의 손가락으로 가리킨다거나 당신의 손으로 문 ? ( : , 손잡이를 열게 함)예아니요
# 10                                                                                          다른 사람들에게는 기이하게 보일 수 있는 것에 관심을 갖거나 집착 몰두한 적이 /있습니까? 예교 통 신호등 배수 파이프 시간표 등(:  ,  ,  )예아니요
# 11                                피검자가 사물을 본래의 기능으로 사용하기보다는 사물이나 장난감의 특정부분에 더 관심을 보인 적이 있습니까 예 자동차의 바퀴를 빙글빙글 돌림? ( : )예아니요\n다음의 행동들에 대해서는 대상자의 만 세의 기간에 초점을 맞추어 주십시오 그때 대상자가 어땠는지를
# 12  . 기억하려면 대상자가 유치원에 입학했다든가 집이 이사를 했다든가크리스마스 때였다든가 그 외에 특히 , , , 가족들의 기억에 남아 있는 중요한 사건들을 기준으로 당시 상황을 잘 회상해 보는 것이 도움이 될 수 있습니다 만약 대상자가 아직 만 세가 되지 않았다면 지난 개월 동안의 행동을 생각해 보시기 바랍니다.
# 13                                                                                              피검자가 또래집단에 비추어 그 내용은 대체로 적절하나 관심의 정도가 유난히 높은 관심거리를 가진 적이 있습니까 예 기차 공룡? ( : , ) 예아니요
# 14                                                                                                           피검자가 물건이나 사람의 생김새 촉감 소리 맛 혹은 냄새에 유별나게 관심을 갖는 , , , 것처럼 보인 적이 있습니까?예아니요
# 15                                                                                                   피검자가 눈앞에서 손가락을 꼬거나 튕기는 것과 같이 손이나 손가락을 움직이는 독특한 버릇 혹은 기이한 행동방식을 가진 적이 있습니까?예아니요
# 16                                                                                                                피검자가 빙글빙글 돌거나 반복해서 위아래로 뛰는 것과 같이 몸 전체의 복잡한 , 움직임을 보인 적이 있습니까?예아니요
# 17                                                                                                                       피검자가 자신의 팔을 물어뜯거나 머리를 부딪치는 것과 같이 고의로 자신을 해한 , 적이 있습니까?예아니요
# 18                                                                                                                         피검자가 부드러운 장난감이나 편안한 담요 이외에항상 가지고 다니려는 물건이 ()  있었습니까?예아니요
# 19                                                                                                                                               피검자에게 절친한 친구 또는 단짝 친구가 있습니까?예아니요\n
# 20                                                                                                                                           피검자가 만 세경이었을 때피검자는 무엇을 얻기 위해서가 아니라 단지
# 21                                                                                                                                             , 친근감을 느끼기 위해 당신과 이야기를 나누곤 했습니까?예아니요
# 22                                                                                                                                        피검자가 만 세경이었을 때피검자는 당신이나 다른 사람들 혹은 당신이 하고
# 23                                                                                                   , , 있는 일을 모방하거나 따라서 행동하곤 했습니까?예진 공 청 소 기 로 청소하기 정원  ( : , 가꾸기 물건 수리하기 등, )예아니요
# 24                                                                                                                                       피검자가 만 세경이었을 때피검자는 갖기를 원하는 것이 아니라 단지 당신에게
# 25                                                                                                                                          , , 보여 주기 위해서 주변에 있는 사물을 가리키곤 했습니까?예아니요
# 26                                                                                                                                                                   피검자가 만 세경이었을 때
# 27                                                                                       ,자신이 원하는 것을 당신에게 알려 주기 위해서  원하는 것을 손으로 가리키거나 당신의 손을 그쪽으로 끌어당기는 것 이외의 다른 제스처를 보이곤 했습니까?예아니요
# 28                                                                                                                                           피검자가 만 세경이었을 때피검자가 예라 는 의미를 나타내려고 고개를
# 29                                                                                                                                                                 , ` ‘끄덕였습니까?예아니요
# 30                                                                                                                                         피검자가 만 세경이었을 때피검자가 아니요 라는 의미를 나타내려고 고개를
# 31                                                                                                                                                                  , ` ‘저었습니까?예아니요
# 32                                                                                                                                       피검자가 만 세경이었을 때피검자가 당신과 함께 무엇을 하거나 이야기를 할 때
# 33                                                                                                                                                  , , 대체로 당신의 얼굴을 직접 바라보았습니까?예아니요
# 34                                                                                                                                         피검자가 만 세경이었을 때누 군가 피검자를 향해 웃으면 피검자도 미소를
# 35                                                                                                                                                                     , 보였습니까?예아니요
# 36                                                                                                                                      피검자가 만 세경이었을 때피검자는 당신의 관심을 끌기 위해 자신이 흥미 있어
# 37                                                                                                                                                    , 하는 물건들을 당신에게 보여주곤 했습니까?예아니요
# 38                                                                                                                                           피검자가 만 세경이었을 때음식 이외의 물건들을 당신과 나누려고 하곤
# 39                                                                                                                                                                    , 했습니까?예아니요\n
# 40                                                                                                                                          피검자가 만 세경이었을 때피검자는 자신이 즐거워하는 일에 당신이 함께
# 41                                                                                                                                                    , 참여하기를 바라는 것처럼 보이곤 했습니까?예아니요
# 42                                                                                                                                       피검자가 만 세경이었을 때당신이 슬프거나 아프면 당신을 위로해 주려고 애를
# 43                                                                                                                                                                   , 쓰곤 했습니까?예아니요
# 44                                                                                                                                        피검자가 만 세경이었을 때무 엇을 원하거나 도움을 필요로 할 경우 당신을
# 45                                                                                                                             , 바라보고 소리를 내거나 말을 하면서 당신의 주의를 끌기 위한 몸짓을 하곤 했습니까?예아니요
# 46                                                                                                                                       피검자가 만 세경이었을 때얼굴 표정의 다양한 정도 또는 얼굴 표정의 범주가
# 47                                                                                                                                                               , ( )정상적이었습니까?예아니요
# 48                                                                                                                                          피검자가 만 세경이었을 때피검자는 무궁화 꽃이 피었습니다 나 얼음땡과
# 49                                                                                                                          , ` ‘ ` ’ 같은 사회적 게임에 자발적으로 참여하고 행동을 따라 하려고 노력했습니까? 예아니요
# 50                                                                                                                                         피검자가 만 세경이었을 때피검자는 가장 놀이나 흉내 내기 놀이를 했습니까
# 51                                                                                                                                                                          , ?예아니요
# 52                                                                                                                                         피검자가 만 세경이었을 때피검자는 자신이 잘 모르는 비슷한 또래의 다른
# 53                                                                                                                                                    , 아이들에게 관심을 갖는 것처럼 보였습니까?예아니요
# 54                                                                                                                                           피검자가 만 세경이었을 때다른 아이가 피검자에게 접근하면 호의적으로
# 55                                                                                                                                                                    , 반응했습니까?예아니요
# 56                                                                                                                                         피검자가 만 세경이었을 때당신이 방으로 들어가서 피검자의 이름을 부르지
# 57                                                                                                                         , 않고이 야 기 하 기 시작해도 대체로 당신을 쳐다보고 당신의 말에 주의를 , 기울였습니까?예아니요
# 58                                                                                                                                       피검자가 만 세경이었을 때피검자는 상대가 무엇을 흉내 내는지 이해하고 있는
# 59                                                                                                                                         , 상태에서 다른 아이와 상상놀이 또는 역할놀이를 하곤 했습니까?예아니요
# 60                                                                                                                                         피검자가 만 세경이었을 때술래잡기나 공놀이처럼 다른 아이들과 무리 지어
# 61                                                                                                                                                       , 하는 게임에 협동적으로 참여했습니까?예아니요

# %% [markdown]
# # Text Preprocessing

# %%
# Data for the DataFrame
data = {
    "Question": [
        "피검자는 현재 짧은 어구나 문장을 사용해서 이야기할 수 있습니까? 만약 아니라면 8번 문제로 건너뛰시오",
        "당신은 피검자와 서로 이야기를 주고 받거나 한 가지 주제에 대해 이어서 이야기하는 식으로 피검자와 양방향의 대화를 나눌 수 있습니까?",
        "피검자가 다소 이상한 구를 사용하거나 같은 말을 반복적으로 이야기 한 적이 있습니까? 다른 사람이 했던 표현이거나 피검자 자신이 만들어 낸 것 모두 해당됨",
        "피검자가 사회적으로 부적절한 질문이나 언급을 한 적이 있습니까? 예: 피검자가 그렇게 하면 곤란한 상황에서 사적인 질문을 하거나 개인 신상에 관한 언급함",
        "피검자가 인칭대명사를 혼동해 쓴 적이 있습니까? 예: 나 물 주세요 대신에 너 물 줄까? 혹은 나 배고파요 대신에 걔가 배고파요 와 같이 표현함",
        "피검자가 지어내거나 스스로 만들어 낸 듯한 말을 사용한 적이 있습니까? 또는 사물을 기이하고 간접적인 방식으로 지칭하거나 말을 은유적인 방식으로 이야기한 적이 있습니까? 예: 눈을 포슬비 라고 말함",
        "피검자가 같은 말을 완전히 같은 방식으로 몇 번씩 이야기하거나 당신에게 같은 말을 몇 번씩 반복해 말하도록 고집한 적이 있습니까?",
        "피검자가 아주 특별한 방식 혹은 특정한 순서대로 하려는 일들이 있었습니까? 또는 당신에게 의식을 행하듯이 반드시 정해진 방식대로 행동할 것을 고집하는 것이 있습니까?",
        "당신이 판단하기에 특정 상황에서 보이는 피검자의 얼굴 표정은 대체로 그 상황에서 적절해 보였습니까?",
        "피검자가 당신의 손을 마치 도구나 자신의 몸의 일부분인 것처럼 사용한 적이 있습니까? 예: 어떤 대상을 당신의 손가락으로 가리킨다거나 당신의 손으로 문 손잡이를 열게 함",
        "다른 사람들에게는 기이하게 보일 수 있는 것에 관심을 갖거나 집착/몰두한 적이 있습니까? 교통 신호등, 배수 파이프, 시간표 등",
        "피검자가 사물을 본래의 기능으로 사용하기보다는 사물이나 장난감의 특정부분에 더 관심을 보인 적이 있습니까 예: 자동차의 바퀴를 빙글빙글 돌림?",
        "피검자가 또래집단에 비추어 그 내용은 대체로 적절하나 관심의 정도가 유난히 높은 관심거리를 가진 적이 있습니까? 예: 기차 공룡",
        "피검자가 물건이나 사람의 생김새 촉감 소리 맛 혹은 냄새에 유별나게 관심을 갖는 것처럼 보인 적이 있습니까?",
        "피검자가 눈앞에서 손가락을 꼬거나 튕기는 것과 같이 손이나 손가락을 움직이는 독특한 버릇 혹은 기이한 행동방식을 가진 적이 있습니까?",
        "피검자가 빙글빙글 돌거나 반복해서 위아래로 뛰는 것과 같이 몸 전체의 복잡한 움직임을 보인 적이 있습니까?",
        "피검자가 자신의 팔을 물어뜯거나 머리를 부딪치는 것과 같이 고의로 자신을 해한 적이 있습니까?",
        "피검자가 부드러운 장난감이나 편안한 담요 이외에 항상 가지고 다니려는 물건이 있었습니까?",
        "피검자에게 절친한 친구 또는 단짝 친구가 있습니까?",
        "피검자가 만 4~5세경이었을 때, 피검자는 무엇을 얻기 위해서가 아니라 단지 친근감을 느끼기 위해 당신과 이야기를 나누곤 했습니까?",
        "피검자가 만 4~5세경이었을 때 피검자는 당신이나 다른 사람들 혹은 당신이 하고 있는 일을 모방하거나 따라서 행동하곤 했습니까? 예: 진공청소기로 청소하기, 정원 가꾸기, 물건 수리하기 등",
        "피검자가 만 4~5세경이었을 때 피검자는 갖기를 원하는 것이 아니라 단지 당신에게 보여 주기 위해서 주변에 있는 사물을 가리키곤 했습니까?",
        "피검자가 만 4~5세경이었을 때 자신이 원하는 것을 당신에게 알려 주기 위해서 원하는 것을 손으로 가리키거나 당신의 손을 그쪽으로 끌어당기는 것 이외의 다른 제스처를 보이곤 했습니까?",
        "피검자가 만 4~5세경이었을 때 피검자가 예 라는 의미를 나타내려고 고개를 끄덕였습니까?",
        "피검자가 만 4~5세경이었을 때 피검자가 아니요 라는 의미를 나타내려고 고개를 끄덕였습니까?",
        "피검자가 만 4~5세경이었을 때 피검자가 당신과 함께 무엇을 하거나 이야기를 할 때 대체로 당신의 얼굴을 직접 바라보았습니까?",
        "피검자가 만 4~5세경이었을 때 누군가 피검자를 향해 웃으면 피검자도 미소를 보였습니까?",
        "피검자가 만 4~5세경이었을 때 피검자는 당신의 관심을 끌기 위해 자신이 흥미 있어 하는 물건들을 당신에게 보여주곤 했습니까?",
        "피검자가 만 4~5세경이었을 때 음식 이외의 물건들을 당신과 나누려고 하곤 했습니까?",
        "피검자가 만 4~5세경이었을 때 피검자는 자신이 즐거워하는 일에 당신이 함께 참여하기를 바라는 것처럼 보이곤 했습니까?",
        "피검자가 만 4~5세경이었을 때 당신이 슬프거나 아프면 당신을 위로해 주려고 애를 쓰곤 했습니까?",
        "피검자가 만 4~5세경이었을 때 무엇을 원하거나 도움을 필요로 할 경우 당신을 바라보고 소리를 내거나 말을 하면서 당신의 주의를 끌기 위한 몸짓을 하곤 했습니까?",
        "피검자가 만 4~5세경이었을 때 얼굴 표정의 다양한 정도 또는 얼굴 표정의 범주가 정상적이었습니까?",
        "피검자가 만 4~5세경이었을 때 피검자는 무궁화 꽃이 피었습니다 나 얼음땡과 같은 사회적 게임에 자발적으로 참여하고 행동을 따라 하려고 노력했습니까?",
        "피검자가 만 4~5세경이었을 때 피검자는 가장 놀이나 흉내 내기 놀이를 했습니까?",
        "피검자가 만 4~5세경이었을 때 피검자는 자신이 잘 모르는 비슷한 또래의 다른 아이들에게 관심을 갖는 것처럼 보였습니까?",
        "피검자가 만 4~5세경이었을 때 다른 아이가 피검자에게 접근하면 호의적으로 반응했습니까?",
        "피검자가 만 4~5세경이었을 때 당신이 방으로 들어가서 피검자의 이름을 부르지 않고 이야기하기 시작해도 대체로 당신을 쳐다보고 당신의 말에 주의를 기울였습니까?",
        "피검자가 만 4~5세경이었을 때 피검자는 상대가 무엇을 흉내 내는지 이해하고 있는 상태에서 다른 아이와 상상놀이 또는 역할놀이를 하곤 했습니까?",
        "피검자가 만 4~5세경이었을 때 술래잡기나 공놀이처럼 다른 아이들과 무리 지어하는 게임에 협동적으로 참여했습니까?"
    ]
}

SCQ_kr = pd.DataFrame(data)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 1000)
SCQ_kr
# Out:
#                                                                                                           Question
# 0                                                        피검자는 현재 짧은 어구나 문장을 사용해서 이야기할 수 있습니까? 만약 아니라면 8번 문제로 건너뛰시오
# 1                                       당신은 피검자와 서로 이야기를 주고 받거나 한 가지 주제에 대해 이어서 이야기하는 식으로 피검자와 양방향의 대화를 나눌 수 있습니까?
# 2                           피검자가 다소 이상한 구를 사용하거나 같은 말을 반복적으로 이야기 한 적이 있습니까? 다른 사람이 했던 표현이거나 피검자 자신이 만들어 낸 것 모두 해당됨
# 3                            피검자가 사회적으로 부적절한 질문이나 언급을 한 적이 있습니까? 예: 피검자가 그렇게 하면 곤란한 상황에서 사적인 질문을 하거나 개인 신상에 관한 언급함
# 4                                 피검자가 인칭대명사를 혼동해 쓴 적이 있습니까? 예: 나 물 주세요 대신에 너 물 줄까? 혹은 나 배고파요 대신에 걔가 배고파요 와 같이 표현함
# 5   피검자가 지어내거나 스스로 만들어 낸 듯한 말을 사용한 적이 있습니까? 또는 사물을 기이하고 간접적인 방식으로 지칭하거나 말을 은유적인 방식으로 이야기한 적이 있습니까? 예: 눈을 포슬비 라고 말함
# 6                                         피검자가 같은 말을 완전히 같은 방식으로 몇 번씩 이야기하거나 당신에게 같은 말을 몇 번씩 반복해 말하도록 고집한 적이 있습니까?
# 7                     피검자가 아주 특별한 방식 혹은 특정한 순서대로 하려는 일들이 있었습니까? 또는 당신에게 의식을 행하듯이 반드시 정해진 방식대로 행동할 것을 고집하는 것이 있습니까?
# 8                                                          당신이 판단하기에 특정 상황에서 보이는 피검자의 얼굴 표정은 대체로 그 상황에서 적절해 보였습니까?
# 9                   피검자가 당신의 손을 마치 도구나 자신의 몸의 일부분인 것처럼 사용한 적이 있습니까? 예: 어떤 대상을 당신의 손가락으로 가리킨다거나 당신의 손으로 문 손잡이를 열게 함
# 10                                         다른 사람들에게는 기이하게 보일 수 있는 것에 관심을 갖거나 집착/몰두한 적이 있습니까? 교통 신호등, 배수 파이프, 시간표 등
# 11                                 피검자가 사물을 본래의 기능으로 사용하기보다는 사물이나 장난감의 특정부분에 더 관심을 보인 적이 있습니까 예: 자동차의 바퀴를 빙글빙글 돌림?
# 12                                         피검자가 또래집단에 비추어 그 내용은 대체로 적절하나 관심의 정도가 유난히 높은 관심거리를 가진 적이 있습니까? 예: 기차 공룡
# 13                                                    피검자가 물건이나 사람의 생김새 촉감 소리 맛 혹은 냄새에 유별나게 관심을 갖는 것처럼 보인 적이 있습니까?
# 14                                      피검자가 눈앞에서 손가락을 꼬거나 튕기는 것과 같이 손이나 손가락을 움직이는 독특한 버릇 혹은 기이한 행동방식을 가진 적이 있습니까?
# 15                                                     피검자가 빙글빙글 돌거나 반복해서 위아래로 뛰는 것과 같이 몸 전체의 복잡한 움직임을 보인 적이 있습니까?
# 16                                                            피검자가 자신의 팔을 물어뜯거나 머리를 부딪치는 것과 같이 고의로 자신을 해한 적이 있습니까?
# 17                                                               피검자가 부드러운 장난감이나 편안한 담요 이외에 항상 가지고 다니려는 물건이 있었습니까?
# 18                                                                                    피검자에게 절친한 친구 또는 단짝 친구가 있습니까?
# 19                                       피검자가 만 4~5세경이었을 때, 피검자는 무엇을 얻기 위해서가 아니라 단지 친근감을 느끼기 위해 당신과 이야기를 나누곤 했습니까?
# 20       피검자가 만 4~5세경이었을 때 피검자는 당신이나 다른 사람들 혹은 당신이 하고 있는 일을 모방하거나 따라서 행동하곤 했습니까? 예: 진공청소기로 청소하기, 정원 가꾸기, 물건 수리하기 등
# 21                                   피검자가 만 4~5세경이었을 때 피검자는 갖기를 원하는 것이 아니라 단지 당신에게 보여 주기 위해서 주변에 있는 사물을 가리키곤 했습니까?
# 22          피검자가 만 4~5세경이었을 때 자신이 원하는 것을 당신에게 알려 주기 위해서 원하는 것을 손으로 가리키거나 당신의 손을 그쪽으로 끌어당기는 것 이외의 다른 제스처를 보이곤 했습니까?
# 23                                                               피검자가 만 4~5세경이었을 때 피검자가 예 라는 의미를 나타내려고 고개를 끄덕였습니까?
# 24                                                             피검자가 만 4~5세경이었을 때 피검자가 아니요 라는 의미를 나타내려고 고개를 끄덕였습니까?
# 25                                          피검자가 만 4~5세경이었을 때 피검자가 당신과 함께 무엇을 하거나 이야기를 할 때 대체로 당신의 얼굴을 직접 바라보았습니까?
# 26                                                               피검자가 만 4~5세경이었을 때 누군가 피검자를 향해 웃으면 피검자도 미소를 보였습니까?
# 27                                          피검자가 만 4~5세경이었을 때 피검자는 당신의 관심을 끌기 위해 자신이 흥미 있어 하는 물건들을 당신에게 보여주곤 했습니까?
# 28                                                                 피검자가 만 4~5세경이었을 때 음식 이외의 물건들을 당신과 나누려고 하곤 했습니까?
# 29                                              피검자가 만 4~5세경이었을 때 피검자는 자신이 즐거워하는 일에 당신이 함께 참여하기를 바라는 것처럼 보이곤 했습니까?
# 30                                                          피검자가 만 4~5세경이었을 때 당신이 슬프거나 아프면 당신을 위로해 주려고 애를 쓰곤 했습니까?
# 31                      피검자가 만 4~5세경이었을 때 무엇을 원하거나 도움을 필요로 할 경우 당신을 바라보고 소리를 내거나 말을 하면서 당신의 주의를 끌기 위한 몸짓을 하곤 했습니까?
# 32                                                         피검자가 만 4~5세경이었을 때 얼굴 표정의 다양한 정도 또는 얼굴 표정의 범주가 정상적이었습니까?
# 33                             피검자가 만 4~5세경이었을 때 피검자는 무궁화 꽃이 피었습니다 나 얼음땡과 같은 사회적 게임에 자발적으로 참여하고 행동을 따라 하려고 노력했습니까?
# 34                                                                   피검자가 만 4~5세경이었을 때 피검자는 가장 놀이나 흉내 내기 놀이를 했습니까?
# 35                                             피검자가 만 4~5세경이었을 때 피검자는 자신이 잘 모르는 비슷한 또래의 다른 아이들에게 관심을 갖는 것처럼 보였습니까?
# 36                                                               피검자가 만 4~5세경이었을 때 다른 아이가 피검자에게 접근하면 호의적으로 반응했습니까?
# 37                       피검자가 만 4~5세경이었을 때 당신이 방으로 들어가서 피검자의 이름을 부르지 않고 이야기하기 시작해도 대체로 당신을 쳐다보고 당신의 말에 주의를 기울였습니까?
# 38                                피검자가 만 4~5세경이었을 때 피검자는 상대가 무엇을 흉내 내는지 이해하고 있는 상태에서 다른 아이와 상상놀이 또는 역할놀이를 하곤 했습니까?
# 39                                                 피검자가 만 4~5세경이었을 때 술래잡기나 공놀이처럼 다른 아이들과 무리 지어하는 게임에 협동적으로 참여했습니까?

# %% [markdown]
# # To English (Used ChatGPT)

# %%
# Data for the DataFrame
translation = {
    "Question": [
        "Can the examinee currently use short phrases or sentences to talk? If not, skip to question 8.",
        "Can you have a two-way conversation with the examinee, where you exchange ideas or continue talking about a single topic?",
        "Has the examinee ever used somewhat strange phrases or repeatedly said the same thing? This includes expressions used by others or created by the examinee.",
        "Has the examinee ever made socially inappropriate questions or remarks? For example, asking personal questions or making personal remarks in a situation where it would be awkward.",
        "Has the examinee ever confused personal pronouns? For example, saying 'Do you want water?' instead of 'I want water' or 'He is hungry' instead of 'I am hungry.'",
        "Has the examinee ever used made-up or seemingly self-created words? Or referred to things in a strange and indirect way, or spoken metaphorically? For example, referring to the eyes as 'drizzling rain.'",
        "Has the examinee insisted on saying the same thing in exactly the same way multiple times or repeatedly urged you to say the same thing?",
        "Does the examinee have a very particular way or a specific order they insist on doing things? Or do they insist on you performing certain actions in a ritualistic, predetermined manner?",
        "In your opinion, do the examinee's facial expressions generally seem appropriate for the situation?",
        "Has the examinee ever used your hand as if it were a tool or part of their own body? For example, pointing at something with your finger or using your hand to open a door handle.",
        "Has the examinee shown interest or become absorbed/obsessed with things that might seem odd to others, such as traffic lights, drainpipes, schedules, etc.?",
        "Has the examinee shown more interest in a specific part of an object or toy than in its intended function? For example, spinning the wheels of a car.",
        "Has the examinee ever had an interest that is generally appropriate for their age group but shown an unusually high level of interest in it? For example, trains, dinosaurs.",
        "Has the examinee appeared to show unusual interest in the appearance, texture, sound, taste, or smell of objects or people?",
        "Has the examinee ever had a peculiar habit or odd way of moving their hands or fingers, such as twisting or flicking their fingers in front of their eyes?",
        "Has the examinee ever shown complex whole-body movements, such as spinning around or repeatedly jumping up and down?",
        "Has the examinee ever intentionally harmed themselves, such as biting their arm or banging their head?",
        "Does the examinee have an object other than a soft toy or a comfortable blanket that they always want to carry with them?",
        "Does the examinee have a best friend or close friend?",
        "When the examinee was around 4-5 years old, did they talk to you not to gain something but just to feel closeness?",
        "When the examinee was around 4-5 years old, did they imitate or follow the actions of you or others, or what you were doing? For example, vacuuming, gardening, fixing things, etc.",
        "When the examinee was around 4-5 years old, did they point to objects around them not because they wanted them, but just to show them to you?",
        "When the examinee was around 4-5 years old, did they use gestures other than pointing with their hand or pulling your hand towards what they wanted to indicate their desires to you?",
        "When the examinee was around 4-5 years old, did they nod to indicate 'yes'?",
        "When the examinee was around 4-5 years old, did they shake their head to indicate 'no'?",
        "When the examinee was around 4-5 years old, did they generally look directly at your face when doing something with you or talking to you?",
        "When the examinee was around 4-5 years old, if someone smiled at the examinee, did they smile back?",
        "When the examinee was around 4-5 years old, did they show you things they were interested in to get your attention?",
        "When the examinee was around 4-5 years old, did they try to share things other than food with you?",
        "When the examinee was around 4-5 years old, did they seem to want you to participate in activities they enjoyed?",
        "When the examinee was around 4-5 years old, did they try to comfort you if you were sad or hurt?",
        "When the examinee was around 4-5 years old, if they wanted something or needed help, did they look at you and make gestures or sounds to get your attention?",
        "When the examinee was around 4-5 years old, were the variety and range of their facial expressions normal?",
        "When the examinee was around 4-5 years old, did they voluntarily participate and try to follow the actions in social games like 'Red Light, Green Light' or 'Statue'?",
        "When the examinee was around 4-5 years old, did they engage in pretend or role-playing games?",
        "When the examinee was around 4-5 years old, did they seem interested in other children of a similar age who they didn't know well?",
        "When the examinee was around 4-5 years old, did they respond positively when another child approached them?",
        "When the examinee was around 4-5 years old, if you entered a room and started talking without calling their name, did they generally look at you and pay attention to what you were saying?",
        "When the examinee was around 4-5 years old, did they engage in imaginative or role-playing games with another child, understanding what the other was pretending to be?",
        "When the examinee was around 4-5 years old, did they cooperatively participate in group games with other children, like tag or ball games?"
    ]
}

SCQ_en = pd.DataFrame(translation)
SCQ_en
# Out:
#                                                                                                                                                                                                       Question
# 0                                                                                                               Can the examinee currently use short phrases or sentences to talk? If not, skip to question 8.
# 1                                                                                    Can you have a two-way conversation with the examinee, where you exchange ideas or continue talking about a single topic?
# 2                                                  Has the examinee ever used somewhat strange phrases or repeatedly said the same thing? This includes expressions used by others or created by the examinee.
# 3                          Has the examinee ever made socially inappropriate questions or remarks? For example, asking personal questions or making personal remarks in a situation where it would be awkward.
# 4                                             Has the examinee ever confused personal pronouns? For example, saying 'Do you want water?' instead of 'I want water' or 'He is hungry' instead of 'I am hungry.'
# 5   Has the examinee ever used made-up or seemingly self-created words? Or referred to things in a strange and indirect way, or spoken metaphorically? For example, referring to the eyes as 'drizzling rain.'
# 6                                                                     Has the examinee insisted on saying the same thing in exactly the same way multiple times or repeatedly urged you to say the same thing?
# 7                    Does the examinee have a very particular way or a specific order they insist on doing things? Or do they insist on you performing certain actions in a ritualistic, predetermined manner?
# 8                                                                                                          In your opinion, do the examinee's facial expressions generally seem appropriate for the situation?
# 9                           Has the examinee ever used your hand as if it were a tool or part of their own body? For example, pointing at something with your finger or using your hand to open a door handle.
# 10                                                 Has the examinee shown interest or become absorbed/obsessed with things that might seem odd to others, such as traffic lights, drainpipes, schedules, etc.?
# 11                                                       Has the examinee shown more interest in a specific part of an object or toy than in its intended function? For example, spinning the wheels of a car.
# 12                                Has the examinee ever had an interest that is generally appropriate for their age group but shown an unusually high level of interest in it? For example, trains, dinosaurs.
# 13                                                                                 Has the examinee appeared to show unusual interest in the appearance, texture, sound, taste, or smell of objects or people?
# 14                                                  Has the examinee ever had a peculiar habit or odd way of moving their hands or fingers, such as twisting or flicking their fingers in front of their eyes?
# 15                                                                                        Has the examinee ever shown complex whole-body movements, such as spinning around or repeatedly jumping up and down?
# 16                                                                                                      Has the examinee ever intentionally harmed themselves, such as biting their arm or banging their head?
# 17                                                                                   Does the examinee have an object other than a soft toy or a comfortable blanket that they always want to carry with them?
# 18                                                                                                                                                       Does the examinee have a best friend or close friend?
# 19                                                                                          When the examinee was around 4-5 years old, did they talk to you not to gain something but just to feel closeness?
# 20                         When the examinee was around 4-5 years old, did they imitate or follow the actions of you or others, or what you were doing? For example, vacuuming, gardening, fixing things, etc.
# 21                                                               When the examinee was around 4-5 years old, did they point to objects around them not because they wanted them, but just to show them to you?
# 22                       When the examinee was around 4-5 years old, did they use gestures other than pointing with their hand or pulling your hand towards what they wanted to indicate their desires to you?
# 23                                                                                                                                 When the examinee was around 4-5 years old, did they nod to indicate 'yes'?
# 24                                                                                                                     When the examinee was around 4-5 years old, did they shake their head to indicate 'no'?
# 25                                                                  When the examinee was around 4-5 years old, did they generally look directly at your face when doing something with you or talking to you?
# 26                                                                                                         When the examinee was around 4-5 years old, if someone smiled at the examinee, did they smile back?
# 27                                                                                         When the examinee was around 4-5 years old, did they show you things they were interested in to get your attention?
# 28                                                                                                          When the examinee was around 4-5 years old, did they try to share things other than food with you?
# 29                                                                                            When the examinee was around 4-5 years old, did they seem to want you to participate in activities they enjoyed?
# 30                                                                                                            When the examinee was around 4-5 years old, did they try to comfort you if you were sad or hurt?
# 31                                                When the examinee was around 4-5 years old, if they wanted something or needed help, did they look at you and make gestures or sounds to get your attention?
# 32                                                                                                  When the examinee was around 4-5 years old, were the variety and range of their facial expressions normal?
# 33                                       When the examinee was around 4-5 years old, did they voluntarily participate and try to follow the actions in social games like 'Red Light, Green Light' or 'Statue'?
# 34                                                                                                               When the examinee was around 4-5 years old, did they engage in pretend or role-playing games?
# 35                                                                          When the examinee was around 4-5 years old, did they seem interested in other children of a similar age who they didn't know well?
# 36                                                                                                 When the examinee was around 4-5 years old, did they respond positively when another child approached them?
# 37                 When the examinee was around 4-5 years old, if you entered a room and started talking without calling their name, did they generally look at you and pay attention to what you were saying?
# 38                                     When the examinee was around 4-5 years old, did they engage in imaginative or role-playing games with another child, understanding what the other was pretending to be?
# 39                                                                  When the examinee was around 4-5 years old, did they cooperatively participate in group games with other children, like tag or ball games?

# %% [markdown]
# # Sentence Transformer

# %%
import torch
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %%
# Check if CUDA is available and set the device accordingly
device = 'cuda' if torch.cuda.is_available() else 'cpu'

data2 = pd.read_csv(r"C:\Users\user\Desktop\vsc\Severance_Hospital\12.21_자폐과제_데이터분석\original\cdb_advanced_ASD_F3.csv")

# %%
# 2. Text Preprocessing
def preprocess_text(text):
    return " ".join([word.lower() for word in text.split()])
data2['Processed_Name'] = data2['Name'].apply(preprocess_text)

# 3. Vectorization using Sentence Transformers
model = SentenceTransformer('all-MiniLM-L6-v2')  # replace with your model
model = model.to(device)  # Move the model to the device
X_full = model.encode(data2['Processed_Name'].tolist(), convert_to_tensor=True)
X_full = X_full.to(device)  # Move X_full to the device

# 4. KMeans clustering with 100 clusters (assuming it was done earlier)
kmeans_100 = KMeans(n_clusters=100, random_state=42).fit(X_full.cpu())  # KMeans requires CPU tensor
data2['100_Cluster'] = kmeans_100.predict(X_full.cpu())  # KMeans requires CPU tensor

# Function to find best matches in dataset based on the processed text and include rank
def match_question_to_data_detailed(question, data2, model, top_n=None):
    question_vec = model.encode([preprocess_text(question)], convert_to_tensor=True)
    question_vec = question_vec.to(device)  # Move tensor to the device
    cosine_similarities = cosine_similarity(question_vec.cpu(), X_full.cpu()).flatten()  # Compute cosine similarity on CPU
    if top_n:
        related_docs_indices = cosine_similarities.argsort()[-top_n:][::-1]
    else:
        related_docs_indices = cosine_similarities.argsort()[::-1]
    matched_data = data2.iloc[related_docs_indices]
    matched_data['Question']= question
    matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
    return matched_data

# Find the best matches for each question with detailed information
question_matches_detailed_ranked = {}
for idx, question in enumerate(SCQ_en['Question']): # Change
    matched_data = match_question_to_data_detailed(question, data2, model)
    question_matches_detailed_ranked[f"Question {idx}"] = matched_data[['ID','Question', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria', 'Matching Rank/Probability', '100_Cluster']]
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Question']= question
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\730085956.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_data['Matching Rank/Probability'] = cosine_similarities[related_docs_indices]

# %%
# 8. Save the results to an Excel file
output_filepath_questions_detailed_ranked = r"C:\Users\user\Desktop\vsc\Severance_Hospital\12.21_자폐과제_데이터분석\output\output_SCQ_ST.xlsx"
writer = pd.ExcelWriter(output_filepath_questions_detailed_ranked, engine='xlsxwriter')
for q_key, matched_data in question_matches_detailed_ranked.items():
    # Add the question as a separate row before the matches
    dataframe = pd.DataFrame([[q_key, None, None, None,None,None, None, None]], columns=['Question','ID', 'Name', 'CUI','DSM5 Criteria','Symptom of DSM5 Criteria',  'Matching Rank/Probability', '100_Cluster'])
    dataframe = pd.concat([dataframe, matched_data], ignore_index=True)
    dataframe.to_excel(writer, sheet_name=q_key, index=False)
writer.save()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21772\2104433962.py:9: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
